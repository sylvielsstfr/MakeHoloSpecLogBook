# %% [markdown]
# # SelectRow_LogBook
#
# - author Sylvie Dagoret-Campagne
# - affiliation : LAL/IN2P3/CNRS
# - Select some row in the generated logbook automatically and select the row having a disperser : it filters note defined disperser
# - creation date : November 22 2018

# %%
import pandas as pd
import numpy as np

# %%
logbook_rootfilename="Logbook_holospec_2018"
logbook_rootfilename_sel="Logbook_holospec_2018_sel"

# %%
file_excel=logbook_rootfilename+".xlsx"
file_csv=logbook_rootfilename+".csv"
file_csv_sel=logbook_rootfilename_sel+".csv"

# %%
df=pd.read_csv(file_csv)

# %%
df
# Out:
#       Unnamed: 0 comment                    datefile  \
# 0              0       ?  2018-06-04T12:37:19.073586
# 1              1       ?  2018-06-07T10:24:01.053834
# 2              2       ?  2018-06-07T10:38:03.528200
# 3              3       ?  2018-06-07T10:26:12.454433
# 4              4       ?  2018-06-07T10:04:56.827194
# 5              5       ?  2018-06-07T10:05:56.234251
# 6              6       ?  2018-06-07T10:10:37.943378
# 7              7       ?  2018-06-07T10:39:04.530849
# 8              8       ?  2018-06-07T10:27:32.339426
# 9              9       ?  2018-06-18T16:01:17.430475
# 10            10       ?  2018-06-18T15:14:51.084651
# 11            11       ?  2018-06-18T15:53:19.817049
# 12            12       ?  2018-06-18T15:47:27.518132
# 13            13       ?  2018-06-18T15:57:30.415923
# 14            14       ?  2018-06-18T16:05:09.746927
# 15            15       ?  2018-06-18T15:53:49.452177
# 16            16       ?  2018-06-18T15:44:44.925425
# ...

# %%
df_sel=df.loc[df['disperser']!='?']

# %%
df_sel
# Out:
#       Unnamed: 0                                            comment  \
# 26            26                                                  ?
# 27            27                                                  ?
# 28            28                                                  ?
# 29            29                                                  ?
# 30            30                                                  ?
# 31            31                                                  ?
# 32            32                                                  ?
# 33            33                                                  ?
# 34            34                                                  ?
# 35            35                                                  ?
# 36            36                                                  ?
# 37            37                                                  ?
# 38            38                                                  ?
# ...

# %%
df_sel.to_csv(file_csv_sel)
